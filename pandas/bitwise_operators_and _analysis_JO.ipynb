# %%
import pandas as pd
from pathlib import Path

# %%
path_ = '/home/success/Downloads/Data_ML/data/athlete_events.csv'

file = pd.read_csv(path_)

# %%
file
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
file.shape
# Out:
# (271116, 15)

# %% [markdown]
# Check if their is any Nan values present inthe Sex column

# %%
print(file["Sex"].isna().any())
# Out:
# False

# %% [markdown]
# Check the possibility of answers

# %%
file["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# With operator AND (&)

# %%
file[(file["Sex"] == "M") & (file["Medal"] == "Gold")]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 3            4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20              Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                             ...  ..   ...     ...     ...
# 270896  135474            Albert Hermann Zrner   M  18.0     NaN     NaN
# 270917  135481     Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270981  135503                 Zurab Zviadauri   M  23.0   182.0    90.0
# 271016  135523  Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                 Henk Jan Zwolle   M  31.0   197.0    93.0
#
#                   Team  NOC        Games  Year  Season         City  \
# ...

# %% [markdown]
# With bitwise (~)

# %%
x = file[~(file["Sex"]== "F") & (file["Medal"] == "Gold")]
x
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 3            4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17         Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20              Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                             ...  ..   ...     ...     ...
# 270896  135474            Albert Hermann Zrner   M  18.0     NaN     NaN
# 270917  135481     Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270981  135503                 Zurab Zviadauri   M  23.0   182.0    90.0
# 271016  135523  Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                 Henk Jan Zwolle   M  31.0   197.0    93.0
#
#                   Team  NOC        Games  Year  Season         City  \
# ...

# %% [markdown]
# if check the most rewards gold medals male:

# %%
x.mode().iloc[0]
# Out:
# ID                          94406
# Name      Michael Fred Phelps, II
# Sex                             M
# Age                          23.0
# Height                      183.0
# Weight                       75.0
# Team                United States
# NOC                           USA
# Games                 1920 Summer
# Year                         1920
# Season                     Summer
# City                       London
# Sport                   Athletics
# Event     Football Men's Football
# Medal                        Gold
# Name: 0, dtype: object

# %% [markdown]
# Show the 10 most winners Male of Gols medals

# %%
top_names = x["Name"].value_counts().head(10)
top_names
# Out:
# Name
# Michael Fred Phelps, II           23
# Raymond Clarence "Ray" Ewry       10
# Mark Andrew Spitz                  9
# Frederick Carlton "Carl" Lewis     9
# Paavo Johannes Nurmi               9
# Matthew Nicholas "Matt" Biondi     8
# Sawao Kato                         8
# Usain St. Leo Bolt                 8
# Ole Einar Bjrndalen                8
# Nikolay Yefimovich Andrianov       7
# Name: count, dtype: int64

# %%
print(top_names.sum())
print(top_names.index)
# Out:
# 99
# Index(['Michael Fred Phelps, II', 'Raymond Clarence "Ray" Ewry',
#        'Mark Andrew Spitz', 'Frederick Carlton "Carl" Lewis',
#        'Paavo Johannes Nurmi', 'Matthew Nicholas "Matt" Biondi', 'Sawao Kato',
#        'Usain St. Leo Bolt', 'Ole Einar Bjrndalen',
#        'Nikolay Yefimovich Andrianov'],
#       dtype='object', name='Name')

# %%
# Assuming 'file' is your DataFrame
#top_names = ['Michael Fred Phelps, II']
data_10_most_winners = x[x['Name'].isin(top_names.index)]
print(data_10_most_winners)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 7512      4198  Nikolay Yefimovich Andrianov   M  19.0   166.0    60.0
# 7518      4198  Nikolay Yefimovich Andrianov   M  23.0   166.0    60.0
# 7520      4198  Nikolay Yefimovich Andrianov   M  23.0   166.0    60.0
# 7521      4198  Nikolay Yefimovich Andrianov   M  23.0   166.0    60.0
# 7524      4198  Nikolay Yefimovich Andrianov   M  23.0   166.0    60.0
# ...        ...                           ...  ..   ...     ...     ...
# 226664  113912             Mark Andrew Spitz   M  22.0   183.0    73.0
# 226665  113912             Mark Andrew Spitz   M  22.0   183.0    73.0
# 226666  113912             Mark Andrew Spitz   M  22.0   183.0    73.0
# 226667  113912             Mark Andrew Spitz   M  22.0   183.0    73.0
# 226668  113912             Mark Andrew Spitz   M  22.0   183.0    73.0
#
#                  Team  NOC        Games  Year  Season      City       Sport  \
# ...

# %%
data_10_most_winners.shape
# Out:
# (99, 15)
