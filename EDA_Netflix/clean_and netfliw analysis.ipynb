# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# Read the csv file and assign the first column as the index

# %%
path_ = '/home/success/Downloads/Data_ML/data/netflix_titles.csv'

data = pd.read_csv(path_, index_col=[0])

# %% [markdown]
# See the first 10 rows of the dataframe

# %%
data.head(10)
# Out:
#             type                             title  \
# show_id
# s1         Movie              Dick Johnson Is Dead
# s2       TV Show                     Blood & Water
# s3       TV Show                         Ganglands
# s4       TV Show             Jailbirds New Orleans
# s5       TV Show                      Kota Factory
# s6       TV Show                     Midnight Mass
# s7         Movie  My Little Pony: A New Generation
# s8         Movie                           Sankofa
# s9       TV Show     The Great British Baking Show
# s10        Movie                      The Starling
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s2                                 NaN
# s3                     Julien Leclercq
# s4                                 NaN
# s5                                 NaN
# s6                       Mike Flanagan
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# ...

# %% [markdown]
# Display dimension of dataframe

# %%
data.shape
# Out:
# (8807, 11)

# %% [markdown]
# Count the numbers of Movie and tv show
# by using loc and name of the column inside
# first Tv Show

# %%
number_tvshow = data.loc[data["type"] == "TV Show"]
print(number_tvshow.index.value_counts())
# Out:
# show_id
# s2       1
# s4974    1
# s4979    1
# s4981    1
# s4985    1
#         ..
# s2581    1
# s2584    1
# s2586    1
# s2587    1
# s8804    1
# Name: count, Length: 2676, dtype: int64

# %% [markdown]
# second movie

# %%
number_movie = data.loc[data["type"] == "Movie"]
print(number_movie.index.value_counts())
# Out:
# show_id
# s1       1
# s6221    1
# s6231    1
# s6230    1
# s6228    1
#         ..
# s3145    1
# s3144    1
# s3143    1
# s3142    1
# s8807    1
# Name: count, Length: 6131, dtype: int64

# %% [markdown]
# Statistics Summary

# %%
data.describe(include="all")
# Out:
#          type                 title       director                cast  \
# count    8807                  8807           6173                7982
# unique      2                  8807           4528                7692
# top     Movie  Dick Johnson Is Dead  Rajiv Chilaka  David Attenborough
# freq     6131                     1             19                  19
# mean      NaN                   NaN            NaN                 NaN
# std       NaN                   NaN            NaN                 NaN
# min       NaN                   NaN            NaN                 NaN
# 25%       NaN                   NaN            NaN                 NaN
# 50%       NaN                   NaN            NaN                 NaN
# 75%       NaN                   NaN            NaN                 NaN
# max       NaN                   NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# ...

# %% [markdown]
# Count the number of nan in each columns

# %%
data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# explore the missing values by create a sub dataframe of ony Nan values from director column

# %%
is_naDirector = data.loc[data["director"].isna()]
is_naDirector
# Out:
#             type                                title director  \
# show_id
# s2       TV Show                        Blood & Water      NaN
# s4       TV Show                Jailbirds New Orleans      NaN
# s5       TV Show                         Kota Factory      NaN
# s11      TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# s15      TV Show      Crime Stories: India Detectives      NaN
# ...          ...                                  ...      ...
# s8796    TV Show                      Yu-Gi-Oh! Arc-V      NaN
# s8797    TV Show                           Yunus Emre      NaN
# s8798    TV Show                            Zak Storm      NaN
# s8801    TV Show                   Zindagi Gulzar Hai      NaN
# s8804    TV Show                          Zombie Dumb      NaN
#
#                                                       cast  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s4                                                     NaN
# ...

# %% [markdown]
# Count the type columns of isnaDirector dataframe by using loc and value_counts()

# %%
isna_Director_movie = is_naDirector.loc[is_naDirector["type"]  == "Movie"]
print(isna_Director_movie["type"].value_counts())
#print(view.value_counts())
# Out:
# type
# Movie    188
# Name: count, dtype: int64

# %%
isna_Director_tvshow = is_naDirector.loc[is_naDirector["type"]  == "TV Show"]
print(isna_Director_tvshow["type"].value_counts())
# Out:
# type
# TV Show    2446
# Name: count, dtype: int64

# %% [markdown]
# display cast NaN

# %%
cast_nan = data.loc[data["cast"].isna()]
cast_nan.head(20)
# Out:
#             type                                              title  \
# show_id
# s1         Movie                               Dick Johnson Is Dead
# s4       TV Show                              Jailbirds New Orleans
# s11      TV Show                Vendetta: Truth, Lies and The Mafia
# s15      TV Show                    Crime Stories: India Detectives
# s17        Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# s21      TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# s46        Movie                             My Heroes Were Cowboys
# s67      TV Show                      Raja Rasoi Aur Anya Kahaniyan
# s70      TV Show                     Stories by Rabindranath Tagore
# s75      TV Show          The World's Most Amazing Vacation Rentals
# s92        Movie                         The Women and the Murderer
# s102       Movie                             Untold: Breaking Point
# s103     TV Show           Countdown: Inspiration4 Mission to Space
# ...

# %% [markdown]
# List the 10 most categories in the "listed_in" columns  with the dataframe Cast NaN

# %%
cast_nan["listed_in"].value_counts().head(10)
# Out:
# listed_in
# Documentaries                                         183
# Documentaries, International Movies                   117
# Docuseries                                             47
# Crime TV Shows, Docuseries                             36
# Reality TV                                             31
# Documentaries, Sports Movies                           30
# Crime TV Shows, Docuseries, International TV Shows     24
# Kids' TV                                               23
# Documentaries, International Movies, Sports Movies     21
# Documentaries, Music & Musicals                        20
# Name: count, dtype: int64

# %% [markdown]
# Display if any duplicated rows in the dataframe

# %%
v = data[data.duplicated()].shape
v
# Out:
# (0, 11)

# %% [markdown]
# ###Bonus: do a dataframe from the implication of french & usa produced

# %%
data
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# List all USA & French tv shows/ movies produced

# %% [markdown]
# Number of Tv Shows/Movie produced by France

# %%
data[(data["country"] == "France")]
# Out:
#             type                       title  \
# show_id
# s92        Movie  The Women and the Murderer
# s189       Movie            2 Alone in Paris
# s274     TV Show               Gone for Good
# s300       Movie                   The Swarm
# s554     TV Show                      Mortel
# ...          ...                         ...
# s8219      Movie         The Boss's Daughter
# s8371      Movie        The Jack King Affair
# s8424    TV Show         The Minimighty Kids
# s8483    TV Show                The Returned
# s8564      Movie                The Workshop
#
#                                    director  \
# show_id
# s92      Mona Achache, Patricia Tourancheau
# s189                Ramzy Bedia, Éric Judor
# s274                     Juan Carlos Medina
# s300                         Just Philippot
# s554                                    NaN
# ...                                     ...
# s8219                       Olivier Loustau
# ...

# %% [markdown]
# Number of Tv Shows/ Movie produced by United States

# %%
USA_number = data[data["country"] == "United States"]
USA_number.shape
# Out:
# (2818, 11)

# %%
v = data.loc[data["country"].str.contains("United States") & data["country"].str.contains("France")]
v
# Out:
#             type                      title        director  \
# show_id
# s30        Movie                   Paranoia  Robert Luketic
# s100     TV Show               On the Verge             NaN
# s123       Movie                 In the Cut    Jane Campion
# s136       Movie                Cliffhanger    Renny Harlin
# s268       Movie                  The Piano    Jane Campion
# ...          ...                        ...             ...
# s8502      Movie  The Secret Life of Pets 2    Chris Renaud
# s8652      Movie                      Tyson    James Toback
# s8704      Movie        We Are Your Friends      Max Joseph
# s8716      Movie        Welcome to New York    Abel Ferrara
# s8798    TV Show                  Zak Storm             NaN
#
#                                                       cast  \
# show_id
# s30      Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# s100     Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
# ...

# %% [markdown]
# Display the older content

# %%
older = data["release_year"].min()
print(older)
# Out:
# 1925

# %%
older_content = data.loc[data["release_year"] == 1925]
print(older_content)
# Out:
#             type                              title director cast country  \
# show_id
# s4251    TV Show  Pioneers: First Women Filmmakers*      NaN  NaN     NaN
#
#                 date_added  release_year rating  duration listed_in  \
# show_id
# s4251    December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                                description
# show_id
# s4251    This collection restores films from women who ...

# %% [markdown]
# Display the longest movie:
#     -> first select all movie
#     -> check if any N/A values
#     -> drop rows contain N/A by using function notna()
#     -> second replace " min" by ""
#     -> replace the str by float
#     -> find the max()

# %%
selection = data.loc[data["type"] == "Movie"]
selection
# Out:
#           type                             title  \
# show_id
# s1       Movie              Dick Johnson Is Dead
# s7       Movie  My Little Pony: A New Generation
# s8       Movie                           Sankofa
# s10      Movie                      The Starling
# s13      Movie                      Je Suis Karl
# ...        ...                               ...
# s8802    Movie                           Zinzana
# s8803    Movie                            Zodiac
# s8805    Movie                        Zombieland
# s8806    Movie                              Zoom
# s8807    Movie                            Zubaan
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s10                     Theodore Melfi
# s13                Christian Schwochow
# ...                                ...
# s8802                  Majid Al Ansari
# ...

# %%
selection.loc[selection["duration"].isna()]
# Out:
#           type                                 title    director        cast  \
# show_id
# s5542    Movie                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# s5795    Movie                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# s5814    Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#                country          date_added  release_year  rating duration  \
# show_id
# s5542    United States       April 4, 2017          2017  74 min      NaN
# s5795    United States  September 16, 2016          2010  84 min      NaN
# s5814    United States     August 15, 2016          2015  66 min      NaN
#
#         listed_in                                        description
# show_id
# s5542      Movies  Louis C.K. muses on religion, eternal love, gi...
# s5795      Movies  Emmy-winning comedy writer Louis C.K. brings h...
# s5814      Movies  The comic puts his trademark hilarious/thought...

# %%
selection = selection[selection["duration"].notna()]
selection
# Out:
#           type                             title  \
# show_id
# s1       Movie              Dick Johnson Is Dead
# s7       Movie  My Little Pony: A New Generation
# s8       Movie                           Sankofa
# s10      Movie                      The Starling
# s13      Movie                      Je Suis Karl
# ...        ...                               ...
# s8802    Movie                           Zinzana
# s8803    Movie                            Zodiac
# s8805    Movie                        Zombieland
# s8806    Movie                              Zoom
# s8807    Movie                            Zubaan
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s10                     Theodore Melfi
# s13                Christian Schwochow
# ...                                ...
# s8802                  Majid Al Ansari
# ...

# %%
duration_column = selection["duration"]
duration_column
# Out:
# show_id
# s1        90 min
# s7        91 min
# s8       125 min
# s10      104 min
# s13      127 min
#           ...
# s8802     96 min
# s8803    158 min
# s8805     88 min
# s8806     88 min
# s8807    111 min
# Name: duration, Length: 6128, dtype: object

# %%
time = pd.Series(duration_column)
time
# Out:
# show_id
# s1        90 min
# s7        91 min
# s8       125 min
# s10      104 min
# s13      127 min
#           ...
# s8802     96 min
# s8803    158 min
# s8805     88 min
# s8806     88 min
# s8807    111 min
# Name: duration, Length: 6128, dtype: object

# %%
duration_column = duration_column.str.replace(" min", "")
duration_column
# Out:
# show_id
# s1        90
# s7        91
# s8       125
# s10      104
# s13      127
#         ...
# s8802     96
# s8803    158
# s8805     88
# s8806     88
# s8807    111
# Name: duration, Length: 6128, dtype: object

# %%
duration_column = duration_column.astype(int)

# %%
duration_column = duration_column.sort_values(ascending=False)
duration_column
# Out:
# show_id
# s4254    312
# s718     273
# s2492    253
# s2488    237
# s2485    233
#         ...
# s3536     10
# s1558      9
# s1485      8
# s2714      5
# s3778      3
# Name: duration, Length: 6128, dtype: int64

# %%
duration_column.index
# Out:
# Index(['s4254', 's718', 's2492', 's2488', 's2485', 's2489', 's167', 's7933',
#        's1020', 's4574',
#        ...
#        's696', 's3776', 's4708', 's6406', 's2859', 's3536', 's1558', 's1485',
#        's2714', 's3778'],
#       dtype='object', name='show_id', length=6128)

# %%
duration_index = duration_column.index
data.loc[duration_index].head(5)
# Out:
#           type                        title                director  \
# show_id
# s4254    Movie   Black Mirror: Bandersnatch                     NaN
# s718     Movie  Headspace: Unwind Your Mind                     NaN
# s2492    Movie       The School of Mischief  Houssam El-Din Mustafa
# s2488    Movie               No Longer kids         Samir Al Asfory
# s2485    Movie           Lock Your Girls In       Fouad El-Mohandes
#
#                                                       cast        country  \
# show_id
# s4254    Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# s718     Andy Puddicombe, Evelyn Lewis Prieto, Ginger D...            NaN
# s2492    Suhair El-Babili, Adel Emam, Saeed Saleh, Youn...          Egypt
# s2488    Said Saleh, Hassan Moustafa, Ahmed Zaki, Youne...          Egypt
# s2485    Fouad El-Mohandes, Sanaa Younes, Sherihan, Ahm...            NaN
#
#                 date_added  release_year rating duration  \
# show_id
# ...

# %% [markdown]
# List categories which have the most contents

# %%
data["listed_in"].shape
# Out:
# (8807,)

# %% [markdown]
# drop N/A values from listed_in column

# %%
listed_in = data[data["listed_in"].notna()]
listed_in
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# **join all categories**

# %%
", ".join(listed_in["listed_in"])
# Out:
# "Documentaries, International TV Shows, TV Dramas, TV Mysteries, Crime TV Shows, International TV Shows, TV Action & Adventure, Docuseries, Reality TV, International TV Shows, Romantic TV Shows, TV Comedies, TV Dramas, TV Horror, TV Mysteries, Children & Family Movies, Dramas, Independent Movies, International Movies, British TV Shows, Reality TV, Comedies, Dramas, Crime TV Shows, Docuseries, International TV Shows, Crime TV Shows, International TV Shows, TV Action & Adventure, Dramas, International Movies, Children & Family Movies, Comedies, British TV Shows, Crime TV Shows, Docuseries, TV Comedies, TV Dramas, Documentaries, International Movies, Crime TV Shows, Spanish-Language TV Shows, TV Dramas, Thrillers, International TV Shows, Spanish-Language TV Shows, TV Action & Adventure, Crime TV Shows, Docuseries, International TV Shows, International TV Shows, TV Action & Adventure, TV Dramas, Comedies, International Movies, Children & Family Movies, Comedies, International Movies, Rom
# ...

# %% [markdown]
# split all categories by their string ", "

# %%
list_ = pd.Series(", ".join(listed_in["listed_in"]).split(", "))
list_
# Out:
# 0                   Documentaries
# 1          International TV Shows
# 2                       TV Dramas
# 3                    TV Mysteries
# 4                  Crime TV Shows
#                    ...
# 19318    Children & Family Movies
# 19319                    Comedies
# 19320                      Dramas
# 19321        International Movies
# 19322            Music & Musicals
# Length: 19323, dtype: object

# %% [markdown]
# **counts values of each categories**

# %%
list_ = list_.value_counts()

# %%
list_.head(5)
# Out:
# International Movies      2752
# Dramas                    2427
# Comedies                  1674
# International TV Shows    1351
# Documentaries              869
# Name: count, dtype: int64

# %% [markdown]
# __Display directors who produced the most contents__

# %% [markdown]
# retake the sub dataframe: is_naDirector

# %%
isDirector_ = data.loc[data["director"].notna()]
isDirector_
# Out:
#             type                             title  \
# show_id
# s1         Movie              Dick Johnson Is Dead
# s3       TV Show                         Ganglands
# s6       TV Show                     Midnight Mass
# s7         Movie  My Little Pony: A New Generation
# s8         Movie                           Sankofa
# ...          ...                               ...
# s8802      Movie                           Zinzana
# s8803      Movie                            Zodiac
# s8805      Movie                        Zombieland
# s8806      Movie                              Zoom
# s8807      Movie                            Zubaan
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s3                     Julien Leclercq
# s6                       Mike Flanagan
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# ...                                ...
# s8802                  Majid Al Ansari
# ...

# %%
is_ListDirector = ", ".join(isDirector_["director"]).split(", ")
is_ListDirector
# Out:
# ['Kirsten Johnson',
#  'Julien Leclercq',
#  'Mike Flanagan',
#  'Robert Cullen',
#  'José Luis Ucha',
#  'Haile Gerima',
#  'Andy Devonshire',
#  'Theodore Melfi',
#  'Kongkiat Komesiri',
#  'Christian Schwochow',
#  'Bruno Garotti',
#  'Pedro de Echave García',
#  'Pablo Azorín Williams',
#  'Adam Salky',
#  'Olivier Megaton',
#  'K.S. Ravikumar',
#  'Alex Woo',
#  'Stanley Moore',
#  'S. Shankar',
#  'Rajiv Menon',
#  'Dennis Dugan',
#  'Scott Stewart',
#  'Robert Luketic',
#  'Ashwiny Iyer Tiwari',
#  'Abhishek Chaubey',
#  'Saket Chaudhary',
#  'Daniel Sandu',
#  'Cédric Jimenez',
#  'George Nolfi',
#  'Steven Spielberg',
#  'Jeannot Szwarc',
#  'Joe Alves',
#  'Joseph Sargent',
#  'Tyler Greco',
#  'Daniel Espinosa',
#  'Bunmi Ajakaiye',
#  'Antoine Fuqua',
#  'Toshiya Shinohara',
#  'Toshiya Shinohara',
#  'Toshiya Shinohara',
#  'Toshiya Shinohara',
#  'Masahiko Murata',
#  'Hajime Kamegaki',
#  'Masahiko Murata',
#  'Hajime Kamegaki',
#  'Masahiko Murata',
# ...

# %%
is_ListDirector = pd.Series(is_ListDirector)
is_ListDirector
# Out:
# 0       Kirsten Johnson
# 1       Julien Leclercq
# 2         Mike Flanagan
# 3         Robert Cullen
# 4        José Luis Ucha
#              ...
# 6973    Majid Al Ansari
# 6974      David Fincher
# 6975    Ruben Fleischer
# 6976       Peter Hewitt
# 6977        Mozez Singh
# Length: 6978, dtype: object

# %%
is_ListDirector = is_ListDirector.value_counts()
is_ListDirector.head(5)
# Out:
# Rajiv Chilaka    22
# Jan Suter        21
# Raúl Campos      19
# Suhas Kadav      16
# Marcus Raboy     16
# Name: count, dtype: int64

# %%
ss = isDirector_.loc[isDirector_["director"].str.contains("Jan Suter")]
ss
# Out:
#           type                                        title  \
# show_id
# s4750    Movie          Coco y Raulito: Carrusel de ternura
# s4782    Movie                Luciano Mellera: Infantiloide
# s4809    Movie  Jani Dueñas: Grandes fracasos de ayer y hoy
# s4850    Movie                     Fernando Sanjiao: Hombre
# s4867    Movie                  Carlos Ballarta: Furia Ñera
# s4941    Movie            Todo lo que sería Lucas Lauriente
# s4963    Movie      Sofía Niño de Rivera: Selección Natural
# s5002    Movie            Malena Pichot: Estupidez compleja
# s5003    Movie             Natalia Valdebenito: El especial
# s5063    Movie                  Sebastián Marcelo Wainraich
# s5067    Movie               Ricardo Quevedo: Hay gente así
# s5077    Movie               Arango y Sanint: Ríase el show
# s5177    Movie                                    Mea Culpa
# s5225    Movie   El Especial de Alex Fernández, el Especial
# ...

# %%
ss.shape
# Out:
# (21, 11)

# %%
list_cast = pd.Series(", ".join(ss["cast"]).split(", "))
cast_number = list_cast.value_counts()

# %%
cast_number.head(5)
# Out:
# Carlos Ballarta         3
# Sofía Niño de Rivera    3
# Ricardo O'Farrill       2
# Coco Celis              1
# Julián Arango           1
# Name: count, dtype: int64

# %% [markdown]
# display 10 most countries produced contents on Netflix:
#     -> find any N/A values
#     -> delete N/A values from country column
#     ->join countries
#     -> count with value_counts()

# %% [markdown]
# display 10 most countries produced contents on Netflix:
#     -> find any N/A values
#     -> delete N/A values from country column
#     ->join countries
#     -> count with value_counts()

# %%
data.loc[data["country"].isna()]
# Out:
#             type                                title  \
# show_id
# s3       TV Show                            Ganglands
# s4       TV Show                Jailbirds New Orleans
# s6       TV Show                        Midnight Mass
# s7         Movie     My Little Pony: A New Generation
# s11      TV Show  Vendetta: Truth, Lies and The Mafia
# ...          ...                                  ...
# s8719      Movie               Westside vs. the World
# s8760      Movie               World's Weirdest Homes
# s8784    TV Show                                 Yoko
# s8786    TV Show                                  YOM
# s8804    TV Show                          Zombie Dumb
#
#                               director  \
# show_id
# s3                     Julien Leclercq
# s4                                 NaN
# s6                       Mike Flanagan
# s7       Robert Cullen, José Luis Ucha
# s11                                NaN
# ...                                ...
# ...

# %%
countries = data.loc[data["country"].notna()]
countries
# Out:
#             type                          title         director  \
# show_id
# s1         Movie           Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show                  Blood & Water              NaN
# s5       TV Show                   Kota Factory              NaN
# s8         Movie                        Sankofa     Haile Gerima
# s9       TV Show  The Great British Baking Show  Andy Devonshire
# ...          ...                            ...              ...
# s8802      Movie                        Zinzana  Majid Al Ansari
# s8803      Movie                         Zodiac    David Fincher
# s8805      Movie                     Zombieland  Ruben Fleischer
# s8806      Movie                           Zoom     Peter Hewitt
# s8807      Movie                         Zubaan      Mozez Singh
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# ...

# %%
ten_most  = pd.Series(", ".join(countries["country"]).split(", "))
ten_most
# Out:
# 0        United States
# 1         South Africa
# 2                India
# 3        United States
# 4                Ghana
#              ...
# 10009           Jordan
# 10010    United States
# 10011    United States
# 10012    United States
# 10013            India
# Length: 10014, dtype: object

# %%
ten_most = ten_most.value_counts()
ten_most
# Out:
# United States     3689
# India             1046
# United Kingdom     804
# Canada             445
# France             393
#                   ...
# Bermuda              1
# Ecuador              1
# Armenia              1
# Mongolia             1
# Montenegro           1
# Name: count, Length: 127, dtype: int64

# %%
ten_most_countries = ten_most.head(10)
ten_most_countries
# Out:
# United States     3689
# India             1046
# United Kingdom     804
# Canada             445
# France             393
# Japan              318
# Spain              232
# South Korea        231
# Germany            226
# Mexico             169
# Name: count, dtype: int64

# %%
ten_most_df = countries.loc[countries["country"].isin(ten_most_countries.index)]
ten_most_df.head(20)
# Out:
#             type                                              title  \
# show_id
# s1         Movie                               Dick Johnson Is Dead
# s5       TV Show                                       Kota Factory
# s9       TV Show                      The Great British Baking Show
# s10        Movie                                       The Starling
# s16      TV Show                                  Dear White People
# s18      TV Show                                    Falsa identidad
# s25        Movie                                              Jeans
# s28        Movie                                          Grown Ups
# s29        Movie                                         Dark Skies
# s33      TV Show                                      Sex Education
# s40      TV Show                                       Chhota Bheem
# s41      TV Show             He-Man and the Masters of the Universe
# s42        Movie                                               Jaws
# ...
